# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/papo1011/semeval2026.git
# %cd semeval2026/
# !git checkout XGB-TF_IDF
#!pip install -r requirements.txt
# !python task_A/main.py
# Out:
# Cloning into 'semeval2026'...
# remote: Enumerating objects: 365, done.
# remote: Counting objects: 100% (365/365), done.
# remote: Compressing objects: 100% (216/216), done.
# remote: Total 365 (delta 203), reused 302 (delta 140), pack-reused 0 (from 0)
# Receiving objects: 100% (365/365), 13.88 MiB | 16.21 MiB/s, done.
# Resolving deltas: 100% (203/203), done.
# /content/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026/semeval2026
# Branch 'XGB-TF_IDF' set up to track remote branch 'XGB-TF_IDF' from 'origin'.
# Switched to a new branch 'XGB-TF_IDF'
# Start Training
# Loading Dataset
# ...
# (500000, 4)
# Train set size: 500000
# Validation set size: 100000
# Test set size: 1000
# Y train size: (500000,)
# Y test size: (1000,)
# X train size: (500000, 10000)
# X test size: (1000, 10000)
# ...
